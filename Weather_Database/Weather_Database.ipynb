# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

#Import the api key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | winslow
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | mehamn
# Processing Record 6 of Set 1 | meulaboh
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | ucluelet
# Processing Record 11 of Set 1 | ilo
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | ranong
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | tandalti
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | nsanje
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | de-kastri
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | marataizes
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | sola
# Processing Record 33 of Set 1 | peddapalli
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 1 | mercedes
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | portland
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | lingdong
# Processing Record 43 of Set 1 | cayenne
# Processing Record 44 of Set 1 | sorland
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | buala
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | naze
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | hami
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | haines junction
# Processing Record 7 of Set 2 | kushmurun
# Processing Record 8 of Set 2 | yeniseysk
# Processing Record 9 of Set 2 | san patricio
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | atar
# Processing Record 12 of Set 2 | avera
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 2 | santa isabel
# Processing Record 17 of Set 2 | la paz
# Processing Record 18 of Set 2 | teya
# Processing Record 19 of Set 2 | fortuna
# Processing Record 20 of Set 2 | san quintin
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | chapleau
# Processing Record 23 of Set 2 | sandwick
# Processing Record 24 of Set 2 | asyut
# Processing Record 25 of Set 2 | takoradi
# Processing Record 26 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | ugoofaaru
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | morant bay
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | angoram
# Processing Record 34 of Set 2 | alta floresta
# Processing Record 35 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | iwanai
# Processing Record 38 of Set 2 | redwater
# Processing Record 39 of Set 2 | terme
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | bandiagara
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | rawson
# Processing Record 47 of Set 2 | bathsheba
# Processing Record 48 of Set 2 | trincomalee
# Processing Record 49 of Set 2 | sulangan
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | makushino
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | gawler
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | jimo
# Processing Record 9 of Set 3 | mnogovershinnyy
# Processing Record 10 of Set 3 | cotonou
# Processing Record 11 of Set 3 | maromitsa
# Processing Record 12 of Set 3 | alofi
# Processing Record 13 of Set 3 | palmerston
# Processing Record 14 of Set 3 | ust-kuyga
# Processing Record 15 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 3 | mecca
# Processing Record 17 of Set 3 | denpasar
# Processing Record 18 of Set 3 | karla
# Processing Record 19 of Set 3 | praia da vitoria
# Processing Record 20 of Set 3 | vieux-habitants
# Processing Record 21 of Set 3 | nioro
# Processing Record 22 of Set 3 | kasongo-lunda
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | lodja
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | guamuchil
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | half moon bay
# Processing Record 29 of Set 3 | vangaindrano
# Processing Record 30 of Set 3 | beloha
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | monze
# Processing Record 33 of Set 3 | sarahan
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | pozo colorado
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | havre-saint-pierre
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | port victoria
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | rudbar
# Processing Record 43 of Set 3 | westport
# Processing Record 44 of Set 3 | bac lieu
# Processing Record 45 of Set 3 | alipur
# Processing Record 46 of Set 3 | chernyshevskiy
# Processing Record 47 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 48 of Set 3 | mana
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | klaksvik
# Processing Record 1 of Set 4 | ayagoz
# Processing Record 2 of Set 4 | caravelas
# Processing Record 3 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 4 of Set 4 | itaituba
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | kununurra
# Processing Record 8 of Set 4 | abu kamal
# Processing Record 9 of Set 4 | herat
# Processing Record 10 of Set 4 | zinder
# Processing Record 11 of Set 4 | saint-georges
# Processing Record 12 of Set 4 | lexington
# Processing Record 13 of Set 4 | bambanglipuro
# Processing Record 14 of Set 4 | roma
# Processing Record 15 of Set 4 | salekhard
# Processing Record 16 of Set 4 | manono
# Processing Record 17 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | kerki
# City not found. Skipping...
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | vardo
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | chifeng
# Processing Record 28 of Set 4 | jacareacanga
# Processing Record 29 of Set 4 | taraz
# Processing Record 30 of Set 4 | taoudenni
# Processing Record 31 of Set 4 | kyabe
# Processing Record 32 of Set 4 | bredasdorp
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | naples
# Processing Record 35 of Set 4 | praia
# Processing Record 36 of Set 4 | waingapu
# Processing Record 37 of Set 4 | makung
# City not found. Skipping...
# Processing Record 38 of Set 4 | yeppoon
# Processing Record 39 of Set 4 | grand-santi
# Processing Record 40 of Set 4 | mananjary
# Processing Record 41 of Set 4 | srednekolymsk
# Processing Record 42 of Set 4 | tabuleiro do norte
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | teguise
# Processing Record 45 of Set 4 | vila velha
# Processing Record 46 of Set 4 | aiquile
# Processing Record 47 of Set 4 | tiksi
# Processing Record 48 of Set 4 | pevek
# Processing Record 49 of Set 4 | hasaki
# Processing Record 50 of Set 4 | gorontalo
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | diu
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | ostrovnoy
# Processing Record 9 of Set 5 | sangar
# Processing Record 10 of Set 5 | hobyo
# Processing Record 11 of Set 5 | lazaro cardenas
# Processing Record 12 of Set 5 | basco
# Processing Record 13 of Set 5 | andenes
# Processing Record 14 of Set 5 | loandjili
# Processing Record 15 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 5 | wajima
# Processing Record 17 of Set 5 | aswan
# Processing Record 18 of Set 5 | flinders
# Processing Record 19 of Set 5 | linxia
# Processing Record 20 of Set 5 | kirensk
# Processing Record 21 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 22 of Set 5 | chokurdakh
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | hukuntsi
# Processing Record 27 of Set 5 | acari
# Processing Record 28 of Set 5 | shahrud
# Processing Record 29 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | waipawa
# Processing Record 31 of Set 5 | fuerte olimpo
# Processing Record 32 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 5 | yerbogachen
# Processing Record 34 of Set 5 | alianca
# City not found. Skipping...
# Processing Record 35 of Set 5 | gat
# Processing Record 36 of Set 5 | shebunino
# Processing Record 37 of Set 5 | visby
# Processing Record 38 of Set 5 | victoria
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | shimoda
# Processing Record 41 of Set 5 | saint george
# Processing Record 42 of Set 5 | oktyabrskiy
# Processing Record 43 of Set 5 | tasiilaq
# Processing Record 44 of Set 5 | bulolo
# Processing Record 45 of Set 5 | cockburn town
# Processing Record 46 of Set 5 | wajir
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | wallaceburg
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 50 of Set 5 | la ronge
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | sanchez
# Processing Record 3 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 6 | kamalasai
# Processing Record 5 of Set 6 | ginda
# Processing Record 6 of Set 6 | betki
# City not found. Skipping...
# Processing Record 7 of Set 6 | luba
# Processing Record 8 of Set 6 | manicore
# Processing Record 9 of Set 6 | stephenville
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | tual
# Processing Record 12 of Set 6 | lacombe
# Processing Record 13 of Set 6 | karratha
# Processing Record 14 of Set 6 | salta
# Processing Record 15 of Set 6 | aksarka
# Processing Record 16 of Set 6 | acarau
# Processing Record 17 of Set 6 | nanakuli
# Processing Record 18 of Set 6 | prieska
# Processing Record 19 of Set 6 | axim
# Processing Record 20 of Set 6 | inndyr
# Processing Record 21 of Set 6 | sept-iles
# Processing Record 22 of Set 6 | chikmagalur
# Processing Record 23 of Set 6 | cocentaina
# Processing Record 24 of Set 6 | faya
# Processing Record 25 of Set 6 | maneadero
# Processing Record 26 of Set 6 | carutapera
# Processing Record 27 of Set 6 | afareaitu
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | andros town
# Processing Record 30 of Set 6 | garcia hernandez
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | kuruman
# Processing Record 34 of Set 6 | hirtshals
# Processing Record 35 of Set 6 | luderitz
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | martinsicuro
# Processing Record 38 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 6 | alyangula
# Processing Record 41 of Set 6 | skeldon
# Processing Record 42 of Set 6 | upernavik
# Processing Record 43 of Set 6 | iracoubo
# Processing Record 44 of Set 6 | fukue
# Processing Record 45 of Set 6 | cabra
# Processing Record 46 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 6 | aripuana
# Processing Record 48 of Set 6 | kon tum
# Processing Record 49 of Set 6 | namatanai
# Processing Record 50 of Set 6 | pochutla
# Processing Record 1 of Set 7 | simao
# Processing Record 2 of Set 7 | castro
# Processing Record 3 of Set 7 | san felipe
# Processing Record 4 of Set 7 | reconquista
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | gushi
# Processing Record 8 of Set 7 | sao joao da barra
# Processing Record 9 of Set 7 | xai-xai
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | mokhsogollokh
# Processing Record 12 of Set 7 | ambatofinandrahana
# Processing Record 13 of Set 7 | bandar-e lengeh
# Processing Record 14 of Set 7 | afua
# Processing Record 15 of Set 7 | mount pleasant
# Processing Record 16 of Set 7 | honiara
# Processing Record 17 of Set 7 | tezu
# Processing Record 18 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 7 | gardelegen
# Processing Record 20 of Set 7 | huambo
# Processing Record 21 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 7 | bourail
# Processing Record 23 of Set 7 | calabozo
# Processing Record 24 of Set 7 | boden
# Processing Record 25 of Set 7 | awjilah
# Processing Record 26 of Set 7 | ponta do sol
# Processing Record 27 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 7 | tabory
# Processing Record 29 of Set 7 | clyde river
# Processing Record 30 of Set 7 | iqaluit
# Processing Record 31 of Set 7 | xuddur
# Processing Record 32 of Set 7 | biltine
# Processing Record 33 of Set 7 | derzhavinsk
# Processing Record 34 of Set 7 | guliston
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | benguela
# Processing Record 37 of Set 7 | puerto del rosario
# Processing Record 38 of Set 7 | callaway
# Processing Record 39 of Set 7 | isangel
# Processing Record 40 of Set 7 | bethel
# Processing Record 41 of Set 7 | tooele
# Processing Record 42 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 43 of Set 7 | vestmannaeyjar
# Processing Record 44 of Set 7 | hazaribag
# Processing Record 45 of Set 7 | moussoro
# Processing Record 46 of Set 7 | darnah
# Processing Record 47 of Set 7 | almaznyy
# Processing Record 48 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | adrar
# Processing Record 50 of Set 7 | lagoa
# Processing Record 1 of Set 8 | mount isa
# Processing Record 2 of Set 8 | wanning
# Processing Record 3 of Set 8 | ilulissat
# Processing Record 4 of Set 8 | talcahuano
# Processing Record 5 of Set 8 | burnie
# Processing Record 6 of Set 8 | kindu
# Processing Record 7 of Set 8 | abu samrah
# Processing Record 8 of Set 8 | talnakh
# Processing Record 9 of Set 8 | egvekinot
# Processing Record 10 of Set 8 | qunduz
# Processing Record 11 of Set 8 | ixtapa
# Processing Record 12 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 8 | dasoguz
# Processing Record 14 of Set 8 | crestview
# Processing Record 15 of Set 8 | lashio
# Processing Record 16 of Set 8 | kadirli
# Processing Record 17 of Set 8 | fort nelson
# Processing Record 18 of Set 8 | brande
# Processing Record 19 of Set 8 | mareeba
# Processing Record 20 of Set 8 | fez
# Processing Record 21 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 8 | vilyuysk
# Processing Record 23 of Set 8 | touros
# Processing Record 24 of Set 8 | pangoa
# Processing Record 25 of Set 8 | merauke
# Processing Record 26 of Set 8 | betare oya
# Processing Record 27 of Set 8 | zhezkazgan
# Processing Record 28 of Set 8 | belmonte
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | unye
# City not found. Skipping...
# Processing Record 31 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 8 | erie
# Processing Record 33 of Set 8 | kautokeino
# Processing Record 34 of Set 8 | satun
# Processing Record 35 of Set 8 | destin
# Processing Record 36 of Set 8 | whitehorse
# Processing Record 37 of Set 8 | morganton
# Processing Record 38 of Set 8 | pauini
# Processing Record 39 of Set 8 | narsaq
# Processing Record 40 of Set 8 | zhelyabovka
# Processing Record 41 of Set 8 | maarianhamina
# Processing Record 42 of Set 8 | luanda
# Processing Record 43 of Set 8 | chenzhou
# Processing Record 44 of Set 8 | sainte-julienne
# Processing Record 45 of Set 8 | dhidhdhoo
# Processing Record 46 of Set 8 | port hardy
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | buchanan
# Processing Record 49 of Set 8 | kemijarvi
# Processing Record 50 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 1 of Set 9 | honningsvag
# Processing Record 2 of Set 9 | vermillion
# Processing Record 3 of Set 9 | mae sai
# Processing Record 4 of Set 9 | necochea
# Processing Record 5 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 9 | high level
# Processing Record 7 of Set 9 | lephepe
# City not found. Skipping...
# Processing Record 8 of Set 9 | korla
# Processing Record 9 of Set 9 | nagato
# Processing Record 10 of Set 9 | rocky mountain house
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | cabedelo
# Processing Record 13 of Set 9 | los llanos de aridane
# Processing Record 14 of Set 9 | pimentel
# Processing Record 15 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 9 | matara
# Processing Record 17 of Set 9 | sao miguel do guama
# Processing Record 18 of Set 9 | popondetta
# Processing Record 19 of Set 9 | lima
# Processing Record 20 of Set 9 | porirua
# Processing Record 21 of Set 9 | damara
# Processing Record 22 of Set 9 | parvatsar
# Processing Record 23 of Set 9 | porto novo
# Processing Record 24 of Set 9 | kropotkin
# Processing Record 25 of Set 9 | ruteng
# Processing Record 26 of Set 9 | lebyazhye
# Processing Record 27 of Set 9 | gravdal
# Processing Record 28 of Set 9 | keti bandar
# Processing Record 29 of Set 9 | halifax
# Processing Record 30 of Set 9 | kjollefjord
# Processing Record 31 of Set 9 | lorengau
# Processing Record 32 of Set 9 | puerto carreno
# Processing Record 33 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 9 | svetlogorsk
# Processing Record 35 of Set 9 | santa cruz del norte
# Processing Record 36 of Set 9 | asau
# Processing Record 37 of Set 9 | manta
# Processing Record 38 of Set 9 | singapore
# Processing Record 39 of Set 9 | formosa
# Processing Record 40 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 9 | port-gentil
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | nome
# Processing Record 44 of Set 9 | kutum
# Processing Record 45 of Set 9 | carmarthen
# Processing Record 46 of Set 9 | sirari
# Processing Record 47 of Set 9 | new smyrna beach
# Processing Record 48 of Set 9 | sistranda
# Processing Record 49 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 9 | aksu
# Processing Record 1 of Set 10 | providencia
# Processing Record 2 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 3 of Set 10 | plouzane
# Processing Record 4 of Set 10 | choma
# Processing Record 5 of Set 10 | zhigansk
# Processing Record 6 of Set 10 | sur
# Processing Record 7 of Set 10 | kushima
# Processing Record 8 of Set 10 | sabang
# Processing Record 9 of Set 10 | cap-aux-meules
# Processing Record 10 of Set 10 | safford
# Processing Record 11 of Set 10 | muzhi
# Processing Record 12 of Set 10 | zheleznodorozhnyy
# Processing Record 13 of Set 10 | lithakia
# Processing Record 14 of Set 10 | vaitape
# Processing Record 15 of Set 10 | feni
# Processing Record 16 of Set 10 | morshansk
# Processing Record 17 of Set 10 | quelimane
# Processing Record 18 of Set 10 | ulaangom
# Processing Record 19 of Set 10 | kosice
# Processing Record 20 of Set 10 | post falls
# Processing Record 21 of Set 10 | gizo
# Processing Record 22 of Set 10 | fairview
# Processing Record 23 of Set 10 | magnor
# Processing Record 24 of Set 10 | kabare
# Processing Record 25 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 10 | tawang
# Processing Record 27 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 10 | paita
# Processing Record 29 of Set 10 | sibu
# Processing Record 30 of Set 10 | rio grande
# Processing Record 31 of Set 10 | kozhva
# Processing Record 32 of Set 10 | samut sakhon
# Processing Record 33 of Set 10 | turbat
# Processing Record 34 of Set 10 | juneau
# Processing Record 35 of Set 10 | maceio
# Processing Record 36 of Set 10 | palmas
# Processing Record 37 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 38 of Set 10 | tongliao
# Processing Record 39 of Set 10 | ayr
# Processing Record 40 of Set 10 | hay river
# Processing Record 41 of Set 10 | abha
# Processing Record 42 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 10 | nelson bay
# Processing Record 44 of Set 10 | iquique
# Processing Record 45 of Set 10 | ames
# Processing Record 46 of Set 10 | berlevag
# Processing Record 47 of Set 10 | roald
# Processing Record 48 of Set 10 | valvedditturai
# Processing Record 49 of Set 10 | caucaia
# Processing Record 50 of Set 10 | huangnihe
# Processing Record 1 of Set 11 | cururupu
# Processing Record 2 of Set 11 | zharkent
# Processing Record 3 of Set 11 | kamenka
# Processing Record 4 of Set 11 | stykkisholmur
# Processing Record 5 of Set 11 | kushalgarh
# Processing Record 6 of Set 11 | porto walter
# Processing Record 7 of Set 11 | waslala
# Processing Record 8 of Set 11 | barra do garcas
# Processing Record 9 of Set 11 | inhambane
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | key largo
# Processing Record 12 of Set 11 | kamina
# Processing Record 13 of Set 11 | brae
# Processing Record 14 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 11 | coahuayana
# Processing Record 16 of Set 11 | lavrentiya
# Processing Record 17 of Set 11 | ballina
# Processing Record 18 of Set 11 | senmonorom
# City not found. Skipping...
# Processing Record 19 of Set 11 | abaete
# Processing Record 20 of Set 11 | casa nova
# Processing Record 21 of Set 11 | barra
# Processing Record 22 of Set 11 | ketchikan
# Processing Record 23 of Set 11 | kermanshah
# Processing Record 24 of Set 11 | qarqin
# Processing Record 25 of Set 11 | codrington
# Processing Record 26 of Set 11 | vao
# Processing Record 27 of Set 11 | maragogi
# Processing Record 28 of Set 11 | saint anthony
# Processing Record 29 of Set 11 | bonavista
# Processing Record 30 of Set 11 | solhan
# Processing Record 31 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 32 of Set 11 | constitucion
# Processing Record 33 of Set 11 | khash
# Processing Record 34 of Set 11 | tarauaca
# Processing Record 35 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 11 | mahon
# Processing Record 37 of Set 11 | camana
# Processing Record 38 of Set 11 | chumikan
# Processing Record 39 of Set 11 | taybad
# Processing Record 40 of Set 11 | qaqortoq
# Processing Record 41 of Set 11 | shingu
# Processing Record 42 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 11 | flin flon
# Processing Record 44 of Set 11 | raga
# Processing Record 45 of Set 11 | urumqi
# Processing Record 46 of Set 11 | turkmenabat
# Processing Record 47 of Set 11 | pechenga
# Processing Record 48 of Set 11 | palauig
# Processing Record 49 of Set 11 | atherton
# Processing Record 50 of Set 11 | pangnirtung
# Processing Record 1 of Set 12 | nago
# Processing Record 2 of Set 12 | maumere
# Processing Record 3 of Set 12 | myitkyina
# Processing Record 4 of Set 12 | huarmey
# Processing Record 5 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 12 | guaruja
# Processing Record 7 of Set 12 | nuevo progreso
# Processing Record 8 of Set 12 | capelinha
# Processing Record 9 of Set 12 | erzin
# Processing Record 10 of Set 12 | haradok
# Processing Record 11 of Set 12 | kashi
# Processing Record 12 of Set 12 | black river
# Processing Record 13 of Set 12 | pontes e lacerda
# Processing Record 14 of Set 12 | ulaanbaatar
# Processing Record 15 of Set 12 | san vicente
# Processing Record 16 of Set 12 | kuala terengganu
# Processing Record 17 of Set 12 | keetmanshoop
# Processing Record 18 of Set 12 | lujan
# Processing Record 19 of Set 12 | akyab
# Processing Record 20 of Set 12 | harper
# Processing Record 21 of Set 12 | hambantota
# Processing Record 22 of Set 12 | kyra
# Processing Record 23 of Set 12 | khasan
# Processing Record 24 of Set 12 | ulladulla
# Processing Record 25 of Set 12 | tuatapere
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | we
# City not found. Skipping...
# Processing Record 28 of Set 12 | poum
# Processing Record 29 of Set 12 | atyrau
# Processing Record 30 of Set 12 | anadyr
# Processing Record 31 of Set 12 | batagay
# Processing Record 32 of Set 12 | ust-kulom
# Processing Record 33 of Set 12 | ko samui
# Processing Record 34 of Set 12 | atbasar
# Processing Record 35 of Set 12 | fare
# Processing Record 36 of Set 12 | davila
# Processing Record 37 of Set 12 | manjacaze
# Processing Record 38 of Set 12 | linguere
# Processing Record 39 of Set 12 | ust-charyshskaya pristan
# Processing Record 40 of Set 12 | calafell
# Processing Record 41 of Set 12 | saint-pierre
# Processing Record 42 of Set 12 | lai
# Processing Record 43 of Set 12 | tsiroanomandidy
# Processing Record 44 of Set 12 | duz
# City not found. Skipping...
# Processing Record 45 of Set 12 | panguna
# Processing Record 46 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 47 of Set 12 | kontagora
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | kedrovyy
# Processing Record 50 of Set 12 | safranbolu
# Processing Record 1 of Set 13 | sacramento
# Processing Record 2 of Set 13 | da nang
# Processing Record 3 of Set 13 | presidencia roque saenz pena
# Processing Record 4 of Set 13 | west plains
# Processing Record 5 of Set 13 | shatoy
# Processing Record 6 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 13 | marsaxlokk
# Processing Record 8 of Set 13 | presidente dutra
# Processing Record 9 of Set 13 | san cristobal
# Processing Record 10 of Set 13 | progreso
# Processing Record 11 of Set 13 | mozelos
# Processing Record 12 of Set 13 | padang
# Processing Record 13 of Set 13 | mendoza
# Processing Record 14 of Set 13 | maiduguri
# Processing Record 15 of Set 13 | shu
# Processing Record 16 of Set 13 | batesville
# Processing Record 17 of Set 13 | baherden
# Processing Record 18 of Set 13 | belawan
# Processing Record 19 of Set 13 | pascagoula
# Processing Record 20 of Set 13 | ajdabiya
# Processing Record 21 of Set 13 | amealco
# Processing Record 22 of Set 13 | balaghat
# Processing Record 23 of Set 13 | iisalmi
# Processing Record 24 of Set 13 | puerto asis
# Processing Record 25 of Set 13 | mahibadhoo
# Processing Record 26 of Set 13 | lata
# Processing Record 27 of Set 13 | koslan
# Processing Record 28 of Set 13 | caohai
# Processing Record 29 of Set 13 | antri
# Processing Record 30 of Set 13 | skuodas
# Processing Record 31 of Set 13 | laguna
# Processing Record 32 of Set 13 | plettenberg bay
# Processing Record 33 of Set 13 | pechora
# Processing Record 34 of Set 13 | kaeo
# Processing Record 35 of Set 13 | kastamonu
# Processing Record 36 of Set 13 | goderich
# Processing Record 37 of Set 13 | penarroya-pueblonuevo
# Processing Record 38 of Set 13 | cody
# Processing Record 39 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 13 | moose factory
# Processing Record 42 of Set 13 | huallanca
# Processing Record 43 of Set 13 | jawhar
# Processing Record 44 of Set 13 | semporna
# Processing Record 45 of Set 13 | ilovlya
# Processing Record 46 of Set 13 | pangani
# Processing Record 47 of Set 13 | timiryazevskoye
# Processing Record 48 of Set 13 | malanje
# Processing Record 49 of Set 13 | naliya
# Processing Record 50 of Set 13 | sobolevo
# Processing Record 1 of Set 14 | trairi
# Processing Record 2 of Set 14 | poso
# Processing Record 3 of Set 14 | nara
# Processing Record 4 of Set 14 | mayo
# Processing Record 5 of Set 14 | yulara
# Processing Record 6 of Set 14 | sisimiut
# Processing Record 7 of Set 14 | margate
# Processing Record 8 of Set 14 | piopio
# Processing Record 9 of Set 14 | amarante do maranhao
# Processing Record 10 of Set 14 | ambon
# Processing Record 11 of Set 14 | nouadhibou
# Processing Record 12 of Set 14 | guerrero negro
# Processing Record 13 of Set 14 | vila
# Processing Record 14 of Set 14 | edson
# Processing Record 15 of Set 14 | asheboro
# Processing Record 16 of Set 14 | kaka
# Processing Record 17 of Set 14 | ahvaz
# Processing Record 18 of Set 14 | noshiro
# Processing Record 19 of Set 14 | marianske lazne
# Processing Record 20 of Set 14 | sosnovo-ozerskoye
# Processing Record 21 of Set 14 | coihaique
# Processing Record 22 of Set 14 | ejura
# Processing Record 23 of Set 14 | graham
# Processing Record 24 of Set 14 | chunskiy
# Processing Record 25 of Set 14 | batagay-alyta
# Processing Record 26 of Set 14 | kalabo
# Processing Record 27 of Set 14 | magadan
# Processing Record 28 of Set 14 | kavieng
# Processing Record 29 of Set 14 | nosy varika
# Processing Record 30 of Set 14 | haldwani
# Processing Record 31 of Set 14 | neiafu
# Processing Record 32 of Set 14 | santa maria
# Processing Record 33 of Set 14 | kincardine
# Processing Record 34 of Set 14 | nueve de julio
# Processing Record 35 of Set 14 | freeport
# Processing Record 36 of Set 14 | pinawa
# Processing Record 37 of Set 14 | wanaka
# Processing Record 38 of Set 14 | vestmanna
# Processing Record 39 of Set 14 | bloemfontein
# Processing Record 40 of Set 14 | lapua
# Processing Record 41 of Set 14 | shaunavon
# Processing Record 42 of Set 14 | biak
# Processing Record 43 of Set 14 | flagstaff
# Processing Record 44 of Set 14 | lavumisa
# Processing Record 45 of Set 14 | price
# Processing Record 46 of Set 14 | pedernales
# Processing Record 47 of Set 14 | aquiraz
# Processing Record 48 of Set 14 | gezing
# Processing Record 49 of Set 14 | tornio
# Processing Record 50 of Set 14 | richards bay
# Processing Record 1 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 15 | churapcha
# Processing Record 3 of Set 15 | shakawe
# Processing Record 4 of Set 15 | zambezi
# Processing Record 5 of Set 15 | borger
# Processing Record 6 of Set 15 | sabzevar
# Processing Record 7 of Set 15 | saint peter
# Processing Record 8 of Set 15 | wainwright
# Processing Record 9 of Set 15 | chapais
# Processing Record 10 of Set 15 | viedma
# Processing Record 11 of Set 15 | tripoli
# Processing Record 12 of Set 15 | wad rawah
# Processing Record 13 of Set 15 | klyuchi
# Processing Record 14 of Set 15 | chara
# Processing Record 15 of Set 15 | bo rai
# Processing Record 16 of Set 15 | hamilton
# Processing Record 17 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 19 of Set 15 | acapulco
# Processing Record 20 of Set 15 | manokwari
# Processing Record 21 of Set 15 | evensk
# Processing Record 22 of Set 15 | port blair
# Processing Record 23 of Set 15 | cairns
# Processing Record 24 of Set 15 | daokou
# Processing Record 25 of Set 15 | jackson
# Processing Record 26 of Set 15 | bamnet narong
# Processing Record 27 of Set 15 | chon buri
# Processing Record 28 of Set 15 | kudahuvadhoo
# Processing Record 29 of Set 15 | boguchany
# Processing Record 30 of Set 15 | araouane
# Processing Record 31 of Set 15 | hailar
# Processing Record 32 of Set 15 | batticaloa
# Processing Record 33 of Set 15 | rovaniemi
# Processing Record 34 of Set 15 | palmer
# Processing Record 35 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 15 | kargasok
# Processing Record 37 of Set 15 | bardstown
# Processing Record 38 of Set 15 | kiunga
# Processing Record 39 of Set 15 | capreol
# Processing Record 40 of Set 15 | fatezh
# Processing Record 41 of Set 15 | karasjok
# Processing Record 42 of Set 15 | kahului
# Processing Record 43 of Set 15 | kigonsera
# Processing Record 44 of Set 15 | messina
# Processing Record 45 of Set 15 | kapustin yar-1
# City not found. Skipping...
# Processing Record 46 of Set 15 | campina grande do sul
# Processing Record 47 of Set 15 | mugur-aksy
# Processing Record 48 of Set 15 | sarkand
# Processing Record 49 of Set 15 | fria
# Processing Record 50 of Set 15 | aranos
# Processing Record 1 of Set 16 | zyryanka
# Processing Record 2 of Set 16 | okitipupa
# Processing Record 3 of Set 16 | natal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     -7.60        71           1
# 1        Albany      US  42.6001  -73.9662     51.80        29          20
# 2       Winslow      US  35.0242 -110.6974     70.00        19           1
# 3        Lompoc      US  34.6391 -120.4579     57.20        51           1
# 4        Mehamn      NO  71.0357   27.8492     31.93        84         100
# 5      Meulaboh      ID   4.1363   96.1285     76.23        89          73
# 6        Kodiak      US  57.7900 -152.4072     37.40        87          90
# 7  Puerto Ayora      EC  -0.7393  -90.3518     84.20        70          20
# 8      Ucluelet      CA  48.9329 -125.5528     48.00        61          75
# 9           Ilo      PE -17.6394  -71.3375     71.60        83           0
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1       14.97          few clouds
# 2       28.77           clear sky
# 3       19.57           clear sky
# 4       14.18          light snow
# 5        5.23       broken clouds
# 6        5.75          light rain
# 7       10.36          few clouds
# 8       20.71       broken clouds
# 9       18.41           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
